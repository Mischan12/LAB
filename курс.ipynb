# %%
# Определение переменных
course_name = "Основы компьютерных наук"
department = "Департамент компьютерных наук"
university = "УГГУ университет"
duration = "Полный день"
format = "Очная форма обучения"

# Преимущества курса
advantages = [
    f"Практическое обучение: В рамках курса студенты будут решать практические задачи, что позволит им применять полученные знания на реальных проектах.",
    f"Индивидуальное внимание: Благодаря небольшим группам и ответственным преподавателям, студенты получат индивидуальное внимание на протяжении всего курса.",
    f"Современные учебные заведения: Наш курс проводится в современных учебных заведениях, что обеспечивает доступ к последним технологиям и ресурсам.",
    f"Возможности карьеры: Окончавшие курс студенты имеют возможность работать в крупных технологических компаниях, таких как Яндекс, Мегаполис ."
]

# Описание курса
course_description = f"Курс {course_name} предназначен для студентов, желающих освоить основы компьютерных наук. В рамках курса студенты будут изучать алгоритмы, структуры данных и программирование."

# Создание продающего текста
text = f"Выберите {course_name} в {department} {university} и получите фундаментальные знания в области компьютерных наук.\n\n"
text += f"Курс длится {duration} и проводится в {format}.\n\n"
text += f"{course_description}\n\n"
text += "Наш курс предлагает множество преимуществ:\n"

for i, advantage in enumerate(advantages):
    text += f"{i+1}. {advantage}\n"

text += "\nНе пропустите возможность начать свою карьеру в области компьютерных наук! Запишитесь на наш курс {course_name} сегодня!"

print(text)
# Out:
# Выберите Основы компьютерных наук в Департамент компьютерных наук XYZ университет и получите фундаментальные знания в области компьютерных наук.
#
# Курс длится Полный день и проводится в Очная форма обучения.
#
# Курс Основы компьютерных наук предназначен для студентов, желающих освоить основы компьютерных наук. В рамках курса студенты будут изучать алгоритмы, структуры данных и программирование.
#
# Наш курс предлагает множество преимуществ:
# 1. Практическое обучение: В рамках курса студенты будут решать практические задачи, что позволит им применять полученные знания на реальных проектах.
# 2. Индивидуальное внимание: Благодаря небольшим группам и ответственным преподавателям, студенты получат индивидуальное внимание на протяжении всего курса.
# 3. Современные учебные заведения: Наш курс проводится в современных учебных заведениях, что обеспечивает доступ к последним технологиям и ресурсам.
# ...
